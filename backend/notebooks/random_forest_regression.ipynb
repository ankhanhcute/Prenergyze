# %%
import numpy as np
import pandas as pd

import os
from pathlib import Path

# %%
BASE_DIR = Path(os.getcwd()).parent.parent

data_path = os.path.join(BASE_DIR, "backend", "data", "processed", "FEATURE_ENGINEERED_DATASET.csv")
data = pd.read_csv(data_path)

# %%
data['date'] = pd.to_datetime(data['date'])

data['year'] = data['date'].dt.year
data['month'] = data['date'].dt.month
data['day'] = data['date'].dt.day
data['hour'] = data['date'].dt.hour
data['day_of_week'] = data['date'].dt.dayofweek

data.drop(['date'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10943 entries, 0 to 10942
# Data columns (total 66 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   load                                     10943 non-null  float64
#  1   temperature_2m                           10943 non-null  float64
#  2   apparent_temperature                     10943 non-null  float64
#  3   relative_humidity_2m                     10943 non-null  float64
#  4   vapour_pressure_deficit                  10943 non-null  float64
#  5   pressure_msl                             10943 non-null  float64
#  6   precipitation                            10943 non-null  float64
#  7   cloud_cover                              10943 non-null  float64
#  8   cloud_cover_low                          10943 non-null  float64
#  9   cloud_cover_mid                          10943 non-null  float64
#  10  cloud_cover_high                         10943 non-null  float64
#  11  et0_fao_evapotranspiration               10943 non-null  float64
#  12  sunshine_duration                        10943 non-null  float64
#  13  wind_speed_10m                           10943 non-null  float64
#  14  wind_gusts_10m                           10943 non-null  float64
#  15  hour_sin                                 10943 non-null  float64
#  16  hour_cos                                 10943 non-null  float64
#  17  dow_sin                                  10943 non-null  float64
#  18  dow_cos                                  10943 non-null  float64
#  19  month_sin                                10943 non-null  float64
#  20  month_cos                                10943 non-null  float64
#  21  wind_dir_cos_10m                         10943 non-null  float64
#  22  wind_dir_sin_10m                         10943 non-null  float64
#  23  wind_dir_cos_10m_roll_mean_3h            10943 non-null  float64
#  24  wind_dir_sin_10m_roll_mean_3h            10943 non-null  float64
#  25  load_lag_1h                              10943 non-null  float64
#  26  load_lag_2h                              10943 non-null  float64
#  27  load_lag_3h                              10943 non-null  float64
#  28  load_lag_24h                             10943 non-null  float64
#  29  load_lag_25h                             10943 non-null  float64
#  30  load_lag_168h                            10943 non-null  float64
#  31  load_roll_std_3h                         10943 non-null  float64
#  32  load_roll_std_24h                        10943 non-null  float64
#  33  load_roll_mean_24h                       10943 non-null  float64
#  34  load_roll_std_168h                       10943 non-null  float64
#  35  load_roll_mean_168h                      10943 non-null  float64
#  36  pressure_msl_lag_24h                     10943 non-null  float64
#  37  temperature_2m_lag_24h                   10943 non-null  float64
#  38  relative_humidity_2m_lag_1h              10943 non-null  float64
#  39  apparent_temperature_lag_24h             10943 non-null  float64
#  40  relative_humidity_2m_lag_24h             10943 non-null  float64
#  41  vapour_pressure_deficit_lag_1h           10943 non-null  float64
#  42  vapour_pressure_deficit_lag_24h          10943 non-null  float64
#  43  pressure_msl_roll_mean_3h                10943 non-null  float64
#  44  pressure_msl_roll_mean_24h               10943 non-null  float64
#  45  temperature_2m_roll_mean_3h              10943 non-null  float64
#  46  temperature_2m_roll_mean_24h             10943 non-null  float64
#  47  apparent_temperature_roll_mean_3h        10943 non-null  float64
#  48  relative_humidity_2m_roll_mean_3h        10943 non-null  float64
#  49  relative_humidity_2m_roll_mean_24h       10943 non-null  float64
#  50  vapour_pressure_deficit_roll_mean_3h     10943 non-null  float64
#  51  vapour_pressure_deficit_roll_mean_24h    10943 non-null  float64
#  52  cloud_cover_roll_mean_3h                 10943 non-null  float64
#  53  wind_gusts_10m_roll_mean_3h              10943 non-null  float64
#  54  wind_speed_10m_roll_mean_3h              10943 non-null  float64
#  55  cloud_cover_low_roll_mean_3h             10943 non-null  float64
#  56  cloud_cover_mid_roll_mean_3h             10943 non-null  float64
#  57  cloud_cover_high_roll_mean_3h            10943 non-null  float64
#  58  sunshine_duration_roll_mean_3h           10943 non-null  float64
#  59  et0_fao_evapotranspiration_roll_mean_3h  10943 non-null  float64
#  60  precipitation_roll_sum_3h                10943 non-null  float64
#  61  year                                     10943 non-null  int32
#  62  month                                    10943 non-null  int32
#  63  day                                      10943 non-null  int32
#  64  hour                                     10943 non-null  int32
#  65  day_of_week                              10943 non-null  int32
# dtypes: float64(61), int32(5)
# memory usage: 5.3 MB

# %%
# Functions to shift and calculate rolling statistics
# min_periods=1 is used to let the rolling func compute values even if there are fewer data than 'window' observations
def past_mean(series, window):
    return series.shift(1).rolling(window, min_periods=1).mean()

def past_std(series, window):
    return series.shift(1).rolling(window, min_periods=1).std()
def past_sum(series, window):
    return series.shift(1).rolling(window, min_periods=1).sum()

# %%
# Shifting all the features to avoid data leakage
# Since we want the current row to only contain info from the past

# load-based
data['load_roll_std_3h']    = past_std(data['load'], 3)
data['load_roll_std_24h']   = past_std(data['load'], 24)
data['load_roll_std_168h']  = past_std(data['load'], 168)
data['load_roll_mean_24h']  = past_mean(data['load'], 24)
data['load_roll_mean_168h'] = past_mean(data['load'], 168)

# wind direction
data['wind_dir_cos_10m_roll_mean_3h'] = past_mean(data['wind_dir_cos_10m'], 3)
data['wind_dir_sin_10m_roll_mean_3h'] = past_mean(data['wind_dir_sin_10m'], 3)

# pressure & temperature
data['pressure_msl_roll_mean_3h']  = past_mean(data['pressure_msl'], 3)
data['pressure_msl_roll_mean_24h'] = past_mean(data['pressure_msl'], 24)
data['temperature_2m_roll_mean_3h']  = past_mean(data['temperature_2m'], 3)
data['temperature_2m_roll_mean_24h'] = past_mean(data['temperature_2m'], 24)

# apparent temp & humidity
data['apparent_temperature_roll_mean_3h']  = past_mean(data['apparent_temperature'], 3)
data['relative_humidity_2m_roll_mean_3h']  = past_mean(data['relative_humidity_2m'], 3)
data['relative_humidity_2m_roll_mean_24h'] = past_mean(data['relative_humidity_2m'], 24)

# VPD
data['vapour_pressure_deficit_roll_mean_3h']  = past_mean(data['vapour_pressure_deficit'], 3)
data['vapour_pressure_deficit_roll_mean_24h'] = past_mean(data['vapour_pressure_deficit'], 24)

# clouds/wind/sun
data['cloud_cover_roll_mean_3h']      = past_mean(data['cloud_cover'], 3)
data['cloud_cover_low_roll_mean_3h']  = past_mean(data['cloud_cover_low'], 3)
data['cloud_cover_mid_roll_mean_3h']  = past_mean(data['cloud_cover_mid'], 3)
data['cloud_cover_high_roll_mean_3h'] = past_mean(data['cloud_cover_high'], 3)
data['wind_gusts_10m_roll_mean_3h']   = past_mean(data['wind_gusts_10m'], 3)
data['wind_speed_10m_roll_mean_3h']   = past_mean(data['wind_speed_10m'], 3)
data['sunshine_duration_roll_mean_3h'] = past_mean(data['sunshine_duration'], 3)
data['et0_fao_evapotranspiration_roll_mean_3h'] = past_mean(data['et0_fao_evapotranspiration'], 3)

# precipitation (sum)
data['precipitation_roll_sum_3h'] = past_sum(data['precipitation'], 3)

# safe lag
data['load_lag_1h']   = data['load'].shift(1)
data['load_lag_2h']   = data['load'].shift(2)
data['load_lag_3h']   = data['load'].shift(3)
data['load_lag_24h']  = data['load'].shift(24)
data['load_lag_25h']  = data['load'].shift(25)
data['load_lag_168h'] = data['load'].shift(168)

data['pressure_msl_lag_24h']            = data['pressure_msl'].shift(24)
data['temperature_2m_lag_24h']          = data['temperature_2m'].shift(24)
data['relative_humidity_2m_lag_1h']     = data['relative_humidity_2m'].shift(1)
data['relative_humidity_2m_lag_24h']    = data['relative_humidity_2m'].shift(24)
data['vapour_pressure_deficit_lag_1h']  = data['vapour_pressure_deficit'].shift(1)
data['vapour_pressure_deficit_lag_24h'] = data['vapour_pressure_deficit'].shift(24)
data['apparent_temperature_lag_24h']    = data['apparent_temperature'].shift(24)

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10775 entries, 168 to 10942
# Data columns (total 66 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   load                                     10775 non-null  float64
#  1   temperature_2m                           10775 non-null  float64
#  2   apparent_temperature                     10775 non-null  float64
#  3   relative_humidity_2m                     10775 non-null  float64
#  4   vapour_pressure_deficit                  10775 non-null  float64
#  5   pressure_msl                             10775 non-null  float64
#  6   precipitation                            10775 non-null  float64
#  7   cloud_cover                              10775 non-null  float64
#  8   cloud_cover_low                          10775 non-null  float64
#  9   cloud_cover_mid                          10775 non-null  float64
#  10  cloud_cover_high                         10775 non-null  float64
#  11  et0_fao_evapotranspiration               10775 non-null  float64
#  12  sunshine_duration                        10775 non-null  float64
#  13  wind_speed_10m                           10775 non-null  float64
#  14  wind_gusts_10m                           10775 non-null  float64
#  15  hour_sin                                 10775 non-null  float64
#  16  hour_cos                                 10775 non-null  float64
#  17  dow_sin                                  10775 non-null  float64
#  18  dow_cos                                  10775 non-null  float64
#  19  month_sin                                10775 non-null  float64
#  20  month_cos                                10775 non-null  float64
#  21  wind_dir_cos_10m                         10775 non-null  float64
#  22  wind_dir_sin_10m                         10775 non-null  float64
#  23  wind_dir_cos_10m_roll_mean_3h            10775 non-null  float64
#  24  wind_dir_sin_10m_roll_mean_3h            10775 non-null  float64
#  25  load_lag_1h                              10775 non-null  float64
#  26  load_lag_2h                              10775 non-null  float64
#  27  load_lag_3h                              10775 non-null  float64
#  28  load_lag_24h                             10775 non-null  float64
#  29  load_lag_25h                             10775 non-null  float64
#  30  load_lag_168h                            10775 non-null  float64
#  31  load_roll_std_3h                         10775 non-null  float64
#  32  load_roll_std_24h                        10775 non-null  float64
#  33  load_roll_mean_24h                       10775 non-null  float64
#  34  load_roll_std_168h                       10775 non-null  float64
#  35  load_roll_mean_168h                      10775 non-null  float64
#  36  pressure_msl_lag_24h                     10775 non-null  float64
#  37  temperature_2m_lag_24h                   10775 non-null  float64
#  38  relative_humidity_2m_lag_1h              10775 non-null  float64
#  39  apparent_temperature_lag_24h             10775 non-null  float64
#  40  relative_humidity_2m_lag_24h             10775 non-null  float64
#  41  vapour_pressure_deficit_lag_1h           10775 non-null  float64
#  42  vapour_pressure_deficit_lag_24h          10775 non-null  float64
#  43  pressure_msl_roll_mean_3h                10775 non-null  float64
#  44  pressure_msl_roll_mean_24h               10775 non-null  float64
#  45  temperature_2m_roll_mean_3h              10775 non-null  float64
#  46  temperature_2m_roll_mean_24h             10775 non-null  float64
#  47  apparent_temperature_roll_mean_3h        10775 non-null  float64
#  48  relative_humidity_2m_roll_mean_3h        10775 non-null  float64
#  49  relative_humidity_2m_roll_mean_24h       10775 non-null  float64
#  50  vapour_pressure_deficit_roll_mean_3h     10775 non-null  float64
#  51  vapour_pressure_deficit_roll_mean_24h    10775 non-null  float64
#  52  cloud_cover_roll_mean_3h                 10775 non-null  float64
#  53  wind_gusts_10m_roll_mean_3h              10775 non-null  float64
#  54  wind_speed_10m_roll_mean_3h              10775 non-null  float64
#  55  cloud_cover_low_roll_mean_3h             10775 non-null  float64
#  56  cloud_cover_mid_roll_mean_3h             10775 non-null  float64
#  57  cloud_cover_high_roll_mean_3h            10775 non-null  float64
#  58  sunshine_duration_roll_mean_3h           10775 non-null  float64
#  59  et0_fao_evapotranspiration_roll_mean_3h  10775 non-null  float64
#  60  precipitation_roll_sum_3h                10775 non-null  float64
#  61  year                                     10775 non-null  int32
#  62  month                                    10775 non-null  int32
#  63  day                                      10775 non-null  int32
#  64  hour                                     10775 non-null  int32
#  65  day_of_week                              10775 non-null  int32
# dtypes: float64(61), int32(5)
# memory usage: 5.3 MB

# %%
from sklearn.model_selection import TimeSeriesSplit

# Quick check to see if the rolling calculations are correct
# and that no data leakage is present
check_one = data['load'].shift(1).rolling(24, min_periods=1).mean()
print("load_roll_mean_24h median abs diff:",
      (data['load_roll_mean_24h'] - check_one).abs().median())

check_two = data['precipitation'].shift(1).rolling(3, min_periods=1).sum()
print("precipitation_roll_sum_3h median abs diff:",
      (data['precipitation_roll_sum_3h'] - check_two).abs().median())

data = data.iloc[168:].reset_index(drop=True)

x = data.drop(['load'], axis=1)
y = data['load']
# Out:
# load_roll_mean_24h median abs diff: 0.0
# precipitation_roll_sum_3h median abs diff: 0.0

# %%
# 4-fold with 1800 test size (hours, 10943 hours in dataset instead 16128 hours converts from 2 years) 
# and 168 gap (hours, prevent leakage due to roll over data)
tscv = TimeSeriesSplit(n_splits=4, test_size=1800, gap=168)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error


rf_rmse_sum = 0
baseline_rmse_sum = 0

grid_params = {
    "n_estimators": [50, 100, 150, 200, 250, 300],
    "max_features": ["sqrt", "log2", 0.5]
}

for fold, (train_index, test_index) in enumerate(tscv.split(x), start=1):
    x_train, x_test = x.iloc[train_index], x.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    rf = RandomForestRegressor()
    inner_tscv = TimeSeriesSplit(n_splits=3)

    grid_search = GridSearchCV(
        estimator=rf,
        param_grid=grid_params,
        cv=inner_tscv,
        scoring='neg_mean_squared_error',
        return_train_score=True
    )

    grid_search.fit(x_train, y_train)

    best_rf = grid_search.best_estimator_

    test_score = best_rf.score(x_test, y_test)

    y_pred = best_rf.predict(x_test)
    rf_rmse = np.sqrt(mean_squared_error(y_test, y_pred))

    baseline = y_test.copy()
    baseline.iloc[0] = y_train.iloc[-1]
    baseline.iloc[1:] = y_test.iloc[:-1].values
    baseline_rmse = np.sqrt(mean_squared_error(y_test, baseline))

    rf_rmse_sum += rf_rmse
    baseline_rmse_sum += baseline_rmse


    print(f"Fold #{fold}: {test_score:.4f}\n")
    print(f"Random Forest RSME: {rf_rmse:.4f}")
    print(f"Baseline Model RSME: {baseline_rmse:.4f}\n")
# Out:
# Fold #1: 0.8587
#
# Random Forest RSME: 1535.8874
# Baseline Model RSME: 1687.4605
#
# Fold #2: 0.9779
#
# Random Forest RSME: 551.1335
# Baseline Model RSME: 1096.1697
#
# Fold #3: 0.9540
#
# Random Forest RSME: 619.8607
# Baseline Model RSME: 1219.0754
#
# Fold #4: 0.9780
#
# Random Forest RSME: 636.5979
# Baseline Model RSME: 1578.1611

# %%
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.preprocessing import StandardScaler
# from sklearn.metrics import mean_squared_error

# rf = RandomForestRegressor()
# scaler = StandardScaler()

# sum_rf_rsme = 0
# sum_baseline_rsme = 0

# for fold, (train_index, test_index) in enumerate(tscv.split(x), start=1):
#     x_train, x_test = x.iloc[train_index], x.iloc[test_index]
#     y_train, y_test = y.iloc[train_index], y.iloc[test_index]

#     x_train_s = scaler.fit_transform(x_train)
#     x_test_s = scaler.transform(x_test)

#     rf.fit(x_train_s, y_train)
#     accuracy = rf.score(x_test_s, y_test)
    
#     y_pred = rf.predict(x_test_s)
#     rf_rsme = np.sqrt(mean_squared_error(y_test, y_pred))

#     baseline = y_test.copy()
#     baseline.iloc[0] = y_train.iloc[-1]
#     baseline.iloc[1:] = y_test.iloc[:-1].values
#     baseline_rsme = np.sqrt(mean_squared_error(y_test, baseline))

#     sum_rf_rsme += rf_rsme
#     sum_baseline_rsme += baseline_rsme

#     print(f"Fold #{fold}: {accuracy:.4f}\n")
#     print(f"Random Forest RSME: {rf_rsme:.4f}")
#     print(f"Baseline Model RSME: {baseline_rsme:.4f}\n")

# %%
avg_rf_rmse = rf_rmse_sum / 4
avg_baseline_rmse = baseline_rmse_sum / 4

print(f"Average Random Forest RSME: {avg_rf_rmse}")
print(f"Average Baseline Model RSME: {avg_baseline_rmse}")
# Out:
# Average Random Forest RSME: 835.8698658089942
# Average Baseline Model RSME: 1395.216683240046
